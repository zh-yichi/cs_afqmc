# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
## water ##
# converged SCF energy = -76.0267469569854
# AFQMC energy: -76.24173 +/- 0.00006

# %%
ccsd_afqmc_cr = -76.24173 + 76.0267469569854
print(ccsd_afqmc_cr)
ccsd_afqmc_err = 0.00006*2
# Out:
# -0.21498304301459825

# %%
lno_thresh = np.array([0.0001,5e-05,3e-05,1e-05,1e-06])
lno_ccsd_afqmc_cr = np.array([-0.202613,-0.211251,-0.213498,-0.214472,-0.214940])-ccsd_afqmc_cr
lno_ccsd_afqmc_mp2_cr = np.array([-0.213817,-0.214611,-0.214893,-0.214856,-0.214945])-ccsd_afqmc_cr
lno_ccsd_afqmc_err = np.array([0.000043,0.000047,0.000046,0.000050,0.000052])*2

# %%
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.plot(x,np.array([0]*100),color='black', linestyle='--')
plt.errorbar(lno_thresh,lno_ccsd_afqmc_cr,yerr=lno_ccsd_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd')
plt.errorbar(lno_thresh,lno_ccsd_afqmc_mp2_cr,yerr=lno_ccsd_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd_mp2')
plt.fill_between(x, np.array([0]*100) + ccsd_afqmc_err, np.array([0]*100) - ccsd_afqmc_err, color='blue', alpha=0.4,label='afqmc_cr')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.title('lno-afqmc/ccsd energy - afmqc/ccsd erngy')
plt.legend()
plt.show()

# %%
## afmqc/rhf ##
# converged SCF energy = -76.0267469569854
# AFQMC energy: -76.2422 +/- 0.0006

# %%
hf_afqmc_cr = -76.2422 + 76.0267469569854
print(hf_afqmc_cr)
hf_afqmc_err = 0.0006*2
# Out:
# -0.21545304301459112

# %%
lno_thresh = np.array([0.0001,5e-05,3e-05,1e-05,1e-06])
lno_hf_afqmc_cr = np.array([-0.203700,-0.211810,-0.214200,-0.214472,-0.215400])-hf_afqmc_cr
lno_hf_afqmc_mp2_cr = np.array([-0.214904,-0.215170,-0.215594,-0.215483,-0.215404])-hf_afqmc_cr
lno_hf_afqmc_err = np.array([0.000424,0.000424,0.000479,0.000480,0.000424])*2

# %%
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.plot(x,np.array([0]*100),color='black', linestyle='--')
plt.errorbar(lno_thresh,lno_hf_afqmc_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/hf')
plt.errorbar(lno_thresh,lno_hf_afqmc_mp2_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/hf_mp2')
plt.fill_between(x, np.array([0]*100) + hf_afqmc_err, np.array([0]*100) - hf_afqmc_err, color='blue', alpha=0.2,label='afqmc_cr')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.title('lno-afqmc/hf energy - afmqc/hf erngy')
plt.legend()
plt.show()

# %%
plt.errorbar(lno_thresh,lno_hf_afqmc_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/hf')
plt.errorbar(lno_thresh,lno_hf_afqmc_mp2_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/hf_mp2')
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.plot(x,np.array([0]*100),color='black', linestyle='--')
plt.fill_between(x, np.array([0]*100) + hf_afqmc_err, np.array([0]*100) - hf_afqmc_err, color='blue', alpha=0.2,label='afqmc/hf_cr')

plt.errorbar(lno_thresh,lno_ccsd_afqmc_cr,yerr=lno_ccsd_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd')
plt.errorbar(lno_thresh,lno_ccsd_afqmc_mp2_cr,yerr=lno_ccsd_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd_mp2')
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.fill_between(x, np.array([0]*100) + ccsd_afqmc_err, np.array([0]*100) - ccsd_afqmc_err, color='blue', alpha=0.4,label='afqmc/ccsd_cr')

plt.title('lno-afqmc energy - afqmc energy')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.legend()
plt.show()

# %%
# dimer
# rhf energy -152.0624906
# dfrhf energy -152.0625362
# AFQMC energy: -152.4948 +/- 0.0001
# dfAFQMC energy: -152.4947

# %%
np.set_printoptions(7,suppress=True)
afqmc_corr = -152.4947 + 152.0624906
print(afqmc_corr)
afqmc_err = 0.0001
# Out:
# -0.43220940000000496

# %%
lno_thresh = np.array([1e-4,5e-05,3e-5,1e-5,1e-06,1e-7,0.0])
lno_afqmc_corr = np.array([-0.405456,-0.420798,-0.424011,-0.428695,-0.430823,-0.430030,-0.432179])
lno_afqmc_mp2_corr = np.array([-0.429703,-0.431019,-0.431139,-0.431545,-0.431132,-0.430060,-0.432178])
lno_afqmc_err = np.array([0.000062,0.000066,0.000066,0.000070,0.000076,0.000084,0.000095])
print(f'lno-threshold: {lno_thresh}')
print(f'lno-afqmc/ccsd correlation energy: {lno_afqmc_corr}')
print(f'mp2 corrected lno-afqmc/ccsd correlation energy: {lno_afqmc_mp2_corr}')
print(f'lno-afqmc/ccsd energy uncertainty (1 sigma): {lno_afqmc_err}')
print(f'afqmc/ccsd correlation energy: {afqmc_corr:.4f} +/- {afqmc_err}')
# Out:
# lno-threshold: [0.0001    0.00005   0.00003   0.00001   0.000001  0.0000001 0.       ]
# lno-afqmc/ccsd correlation energy: [-0.405456 -0.420798 -0.424011 -0.428695 -0.430823 -0.43003  -0.432179]
# mp2 corrected lno-afqmc/ccsd correlation energy: [-0.429703 -0.431019 -0.431139 -0.431545 -0.431132 -0.43006  -0.432178]
# lno-afqmc/ccsd energy uncertainty (1 sigma): [0.000062 0.000066 0.000066 0.00007  0.000076 0.000084 0.000095]
# afqmc/ccsd correlation energy: -0.4322 +/- 0.0001

# %%
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.plot(x,np.array([afqmc_corr]*100),color='black', linestyle='--')
plt.errorbar(lno_thresh[:5],lno_afqmc_corr[:5],yerr=lno_afqmc_err[:5],fmt='o',capsize=5,label='lno_afqmc/ccsd')
plt.errorbar(lno_thresh[:5],lno_afqmc_mp2_corr[:5],yerr=lno_afqmc_err[:5],fmt='o',capsize=5,label='lno_afqmc/ccsd_mp2')
plt.plot(lno_thresh[6],lno_afqmc_corr[6],'o', color='r',markersize=10,label='thresh=0')
plt.fill_between(x, np.array([afqmc_corr]*100) + afqmc_err, np.array([afqmc_corr]*100) - afqmc_err, color='blue', alpha=0.4,label='afqmc_cr')
# plt.xscale('log')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.title('lno-afqmc/ccsd energy')
plt.legend()
plt.show()

# %%
# non-interactive
# AFQMC energy: -152.4834 +/- 0.0001
# converged SCF energy = -152.05327162245

# %%
np.set_printoptions(7,suppress=True)
afqmc_int = -152.4947 - -152.4834
print(afqmc_int)
afqmc_err = 0.0001*np.sqrt(2)
afqmc_corr2 = -152.4834- -152.05327162245
afqmc_err2 = 0.0001
print(afqmc_corr2)
# Out:
# -0.011300000000005639
# -0.4301283775499769

# %%
lno_thresh = np.array([1e-4,5e-05,3e-5,1e-5,1e-06,1e-7,0])
lno_afqmc_corr2 = np.array([-0.406938,-0.422297,-0.424907,-0.428819,-0.429962,-0.430048,-0.430116])
lno_afqmc_mp2_corr2 = np.array([-0.427953,-0.429404,-0.429437,-0.429654,-0.429966,-0.430048,-0.430116])
lno_afqmc_err2 = np.array([0.000059,0.000067,0.000067,0.000070,0.000071,0.000072,0.000093])
print(f'lno-threshold: {lno_thresh}')
print(f'lno-afqmc/ccsd correlation energy: {lno_afqmc_corr2}')
print(f'mp2 corrected lno-afqmc/ccsd correlation energy: {lno_afqmc_mp2_corr2}')
print(f'lno-afqmc/ccsd energy uncertainty (1 sigma): {lno_afqmc_err2}')
print(f'afqmc/ccsd correlation energy: {afqmc_corr2:.4f} +/- {afqmc_err2}')
# Out:
# lno-threshold: [0.0001    0.00005   0.00003   0.00001   0.000001  0.0000001]
# lno-afqmc/ccsd correlation energy: [-0.406938 -0.422297 -0.424907 -0.428819 -0.429962 -0.430048]
# mp2 corrected lno-afqmc/ccsd correlation energy: [-0.427953 -0.429404 -0.429437 -0.429654 -0.429966 -0.430048]
# lno-afqmc/ccsd energy uncertainty (1 sigma): [0.000059 0.000067 0.000067 0.00007  0.000071 0.000072]
# afqmc/ccsd correlation energy: -0.4301 +/- 0.0001

# %%
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
# plt.plot(x,np.array([afqmc_corr]*100),color='black', linestyle='--')
plt.errorbar(lno_thresh,lno_afqmc_corr2,yerr=lno_afqmc_err2,fmt='o',capsize=5,label='lno_afqmc/ccsd')
plt.errorbar(lno_thresh,lno_afqmc_mp2_corr2,yerr=lno_afqmc_err2,fmt='o',capsize=5,label='lno_afqmc/ccsd_mp2')
#plt.plot(lno_thresh,lno_afqmc_corr2,'o', color='r',markersize=10,label='thresh=0')
plt.fill_between(x, np.array([afqmc_corr2]*100) + afqmc_err2, 
                 np.array([afqmc_corr2]*100) - afqmc_err2, color='blue', alpha=0.4,label='afqmc_cr')
plt.xscale('log')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.title('lno-afqmc/ccsd energy')
plt.legend()
plt.show()

# %%
lno_afqmc_corr1 = lno_afqmc_corr
lno_afqmc_mp2_corr1 = lno_afqmc_mp2_corr
lno_afqmc_err1 = lno_afqmc_corr

# %%
# afqmc/rhf -152.4958 +/- 0.0001

# %%
hf_afqmc_cr = -152.4958 + 152.062490646928
print(hf_afqmc_cr)
hf_afqmc_err = 0.0001*2
# Out:
# -0.4333093530719907

# %%
lno_thresh = np.array([0.0001,5e-05,3e-05,1e-05,1e-06])
lno_hf_afqmc_cr = np.array([-0.4063,-0.4218,-0.4257,-0.4304,-0.4334])
lno_hf_afqmc_mp2_cr = np.array([-0.43054,-0.432021,-0.43282,-0.43325,-0.43371])
lno_hf_afqmc_err = np.array([0.000412,0.000412,0.000447,0.000447,0.000479])*2

# %%
print(lno_ccsd_afqmc_mp2_cr-lno_ccsd_afqmc_cr)
print(lno_hf_afqmc_mp2_cr-lno_hf_afqmc_cr)
# Out:
# [-0.024247 -0.010221 -0.007128 -0.00285  -0.000309]
# [-0.02424  -0.010221 -0.00712  -0.00285  -0.00031 ]

# %%
x = np.linspace(max(lno_thresh),min(lno_thresh),100)
plt.plot(x,np.array([hf_afqmc_cr]*100),color='black', linestyle='--')
plt.errorbar(lno_thresh,lno_hf_afqmc_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd')
plt.errorbar(lno_thresh,lno_hf_afqmc_mp2_cr,yerr=lno_hf_afqmc_err,fmt='o',capsize=5,label='lno_afqmc/ccsd_mp2')
plt.fill_between(x, np.array([hf_afqmc_cr]*100) + hf_afqmc_err, np.array([hf_afqmc_cr]*100) - hf_afqmc_err, color='blue', alpha=0.4,label='afqmc_cr')
plt.xlabel('lno_thresh')
plt.ylabel('energy (Hartree)')
plt.title('lno-afqmc/hf correlation energy')
plt.legend()
plt.show()

# %%
# converged SCF energy = -3.18347345728699
# AFQMC energy: -3.26780 +/- 0.00005
# lno-afqmc: -0.084132 +/- 0.000036
-3.26774- -3.18347345728699
# Out:
# -0.08426654271301004

# %%
# -0.101202 +/- 0.000058
