# %%
from pyscf import gto, scf, cc
import numpy as np
from jax import numpy as jnp
from jax import vmap, jvp, jit
import jax
from functools import partial

a = 1.4 # 2aB
nH = 2
atoms = ""
for i in range(nH):
    atoms += f"H {i*a:.5f} 0.00000 0.00000 \n"

mol = gto.M(atom=atoms, basis="sto6g", unit='A', spin=0, verbose=4)
mol.build()

mf = scf.RHF(mol)
mf.kernel()

mo = mf.stability()[0]
dm = mf.make_rdm1(mo,mf.mo_occ)
mf.kernel(dm0=dm)
mo = mf.stability()[0]
dm = mf.make_rdm1(mo,mf.mo_occ)
mf.kernel(dm0=dm)


nfrozen = 0
mycc = cc.CCSD(mf,frozen=nfrozen)
mycc.kernel()
et = mycc.ccsd_t()
print(mycc.e_tot + et)
# Out:
# System: uname_result(system='Linux', node='sharmagroup-rn', release='6.14.0-37-generic', version='#37~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Nov 20 10:25:38 UTC 2', machine='x86_64')  Threads 16
# Python 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0]
# numpy 2.3.1  scipy 1.16.2  h5py 3.14.0
# Date: Fri Jan 23 17:07:02 2026
# PySCF version 2.11.0
# PySCF path  /home/sharmagroup/sharmagroup/pyscf
# GIT HEAD (branch master) 3d1768f5e33b144b606c3d2c81c12ee54d794501
#
# [ENV] PYSCF_EXT_PATH /home/sharmagroup/sharmagroup/pyscf-forge
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 2
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = A
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 H      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# [INPUT]  2 H      1.400000000000   0.000000000000   0.000000000000 AA    2.645616574391   0.000000000000   0.000000000000 Bohr   0.0
#
# nuclear repulsion = 0.377983722085714
# number of shells = 2
# number of NR pGTOs = 12
# number of NR cGTOs = 2
# basis = sto6g
# ecp = {}
# CPU time:         0.53
#
#
# ******** <class 'pyscf.scf.hf.RHF'> ********
# method = RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpr6t6vshf
# max_memory 4000 MB (current use 259 MB)
# Set gradient conv threshold to 3.16228e-05
# Initial guess from minao.
# init E= -0.614776738950177
#   HOMO = -0.278422035704423  LUMO = 0.143766341183144
# cycle= 1 E= -0.949149793634531  delta_E= -0.334  |g|= 3.33e-16  |ddm|= 1.01
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# cycle= 2 E= -0.949149793634531  delta_E= -2.22e-16  |g|=    0  |ddm|= 4.71e-16
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# Extra cycle  E= -0.949149793634531  delta_E= 2.22e-16  |g|= 1.11e-16  |ddm|= 3.68e-16
# converged SCF energy = -0.949149793634531
# rhf_internal: lowest eigs of H = [2.93606191]
# <class 'pyscf.scf.hf.RHF'> wavefunction is stable in the internal stability analysis
#
#
# ******** <class 'pyscf.scf.hf.RHF'> ********
# method = RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpr6t6vshf
# max_memory 4000 MB (current use 283 MB)
# Set gradient conv threshold to 3.16228e-05
# init E= -0.949149793634531
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# cycle= 1 E= -0.949149793634531  delta_E=    0  |g|= 1.11e-16  |ddm|=    0
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# Extra cycle  E= -0.949149793634531  delta_E=    0  |g|= 1.11e-16  |ddm|=    0
# converged SCF energy = -0.949149793634531
# rhf_internal: lowest eigs of H = [2.93606191]
# <class 'pyscf.scf.hf.RHF'> wavefunction is stable in the internal stability analysis
#
#
# ******** <class 'pyscf.scf.hf.RHF'> ********
# method = RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmpr6t6vshf
# max_memory 4000 MB (current use 284 MB)
# Set gradient conv threshold to 3.16228e-05
# init E= -0.949149793634531
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# cycle= 1 E= -0.949149793634531  delta_E=    0  |g|= 1.11e-16  |ddm|=    0
#   HOMO = -0.381137599235758  LUMO = 0.253515513412968
# Extra cycle  E= -0.949149793634531  delta_E=    0  |g|= 1.11e-16  |ddm|=    0
# converged SCF energy = -0.949149793634531
#
# ******** <class 'pyscf.cc.ccsd.CCSD'> ********
# CC2 = 0
# CCSD nocc = 1, nmo = 2
# frozen orbitals 0
# max_cycle = 50
# direct = 0
# conv_tol = 1e-07
# conv_tol_normt = 1e-05
# diis_space = 6
# diis_start_cycle = 0
# diis_start_energy_diff = 1e+09
# max_memory 4000 MB (current use 284 MB)
# Init t2, MP2 energy = -0.988418191945004  E_corr(MP2) -0.0392683983104732
# Init E_corr(CCSD) = -0.0392683983104732
# cycle = 1  E_corr(CCSD) = -0.0589036856585295  dE = -0.0196352873  norm(t1,t2) = 0.0879493
# cycle = 2  E_corr(CCSD) = -0.0678106742774649  dE = -0.00890698862  norm(t1,t2) = 0.0398957
# cycle = 3  E_corr(CCSD) = -0.074561158781969  dE = -0.0067504845  norm(t1,t2) = 0.0172004
# cycle = 4  E_corr(CCSD) = -0.0744469015617096  dE = 0.00011425722  norm(t1,t2) = 0.00037298
# cycle = 5  E_corr(CCSD) = -0.0744345511242165  dE = 1.23504375e-05  norm(t1,t2) = 7.28605e-05
# cycle = 6  E_corr(CCSD) = -0.0744297880020007  dE = 4.76312222e-06  norm(t1,t2) = 4.04251e-05
# cycle = 7  E_corr(CCSD) = -0.0744272661390818  dE = 2.52186292e-06  norm(t1,t2) = 2.79162e-05
# cycle = 8  E_corr(CCSD) = -0.0744187855573432  dE = 8.48058174e-06  norm(t1,t2) = 2.12934e-05
# cycle = 9  E_corr(CCSD) = -0.0744191599057866  dE = -3.74348443e-07  norm(t1,t2) = 9.7769e-07
# cycle = 10  E_corr(CCSD) = -0.0744191579514023  dE = 1.95438436e-09  norm(t1,t2) = 5.386e-09
# CCSD converged
# E(CCSD) = -1.023568951585933  E_corr = -0.07441915795140226
# CCSD(T) correction = -4.79162661909136e-48
# -1.023568951585933

# %%
# example for PT2
options = {'n_eql': 3,
           'n_prop_steps': 50,
            'n_ene_blocks': 1,
            'n_sr_blocks': 5,
            'n_blocks': 50,
            'n_walkers': 50,
            'seed': 2,
            'walker_type': 'rhf',
            'trial': 'cisd',
            'dt':0.005,
            'free_projection':False,
            'ad_mode':None,
            'use_gpu': False,
            }

from ad_afqmc.prop_unrestricted import prop_unrestricted
prop_unrestricted.prep_afqmc(mycc,options,chol_cut=1e-5)
# prop_unrestricted.run_afqmc(options,nproc=1)
option_file='options.bin'
import pickle
with open(option_file, 'wb') as f:
    pickle.dump(options, f)
# Out:
# #
# # Preparing AFQMC calculation
# # If you import pyscf cc modules and use MPI for AFQMC in the same script, finalize MPI before calling the AFQMC driver.
# # Calculating Cholesky integrals
# # Finished calculating Cholesky integrals
# #
# # Size of the correlation space:
# # Number of electrons: (1, 1)
# # Number of basis functions: 2
# # Number of Cholesky vectors: 3
# #
# /home/sharmagroup/sharmagroup/cs_afqmc/ad_afqmc/pyscf_interface.py:567: RuntimeWarning: divide by zero encountered in divide
#   chol_vecs[nchol + 1] = (Munu0 - R) / (delta_max) ** 0.5
# /home/sharmagroup/sharmagroup/cs_afqmc/ad_afqmc/pyscf_interface.py:567: RuntimeWarning: invalid value encountered in divide
#   chol_vecs[nchol + 1] = (Munu0 - R) / (delta_max) ** 0.5

# %%
import numpy as np
from jax import random
from jax import numpy as jnp
from functools import partial
from ad_afqmc import config, stat_utils
from ad_afqmc.prop_unrestricted import prop_unrestricted, sampling
import time

# %%
config.setup_jax()
MPI = config.setup_comm()
comm = MPI.COMM_WORLD
size = comm.Get_size()
rank = comm.Get_rank()

print = partial(print, flush=True)

ham_data, ham, prop, trial, wave_data, sampler, observable, options, _ = (
    prop_unrestricted._prep_afqmc())

init_time = time.time()
comm = MPI.COMM_WORLD
rank = comm.Get_rank()
size = comm.Get_size()

### initialize propagation
seed = options["seed"]
init_walkers = None
trial_rdm1 = trial.get_rdm1(wave_data)
if "rdm1" not in wave_data:
    wave_data["rdm1"] = trial_rdm1
ham_data = ham.build_measurement_intermediates(ham_data, trial, wave_data)
ham_data = ham.build_propagation_intermediates(ham_data, prop, trial, wave_data)
h0 = ham_data['h0']

prop_data = prop.init_prop_data(trial, wave_data, ham_data, init_walkers)
if jnp.abs(jnp.sum(prop_data["overlaps"])) < 1.0e-6:
    raise ValueError(
        "Initial overlaps are zero. Pass walkers with non-zero overlap."
    )
prop_data["key"] = random.PRNGKey(seed + rank)

prop_data["overlaps"] = trial.calc_overlap(prop_data["walkers"], wave_data)
prop_data["n_killed_walkers"] = 0
e_init = trial._calc_energy_restricted(
    prop_data['walkers'][0], ham_data, wave_data)

prop_data["e_estimate"] = e_init
prop_data["pop_control_ene_shift"] = prop_data["e_estimate"]
# Out:
# # Hostname: sharmagroup-rn
# # System Type: Linux
# # Machine Type: x86_64
# # Processor: x86_64
# # Hostname: sharmagroup-rn
# # System Type: Linux
# # Machine Type: x86_64
# # Processor: x86_64
# # Number of MPI ranks: 1
# #
# # norb: 2
# # nelec: (1, 1)
# #
# # n_eql: 3
# # n_prop_steps: 50
# # n_ene_blocks: 1
# # n_sr_blocks: 5
# # n_blocks: 50
# # n_walkers: 50
# # seed: 2
# # walker_type: rhf
# # trial: cisd
# # dt: 0.005
# # free_projection: False
# # use_gpu: False
# # n_exp_terms: 6
# # orbital_rotation: True
# # do_sr: True
# # symmetry: False
# # save_walkers: False
# # ene0: 0.0
# # n_batch: 1
# # LNO: False
# # orbE: 0
# # maxError: 0.001
# #
# (-1.0235689515859332+0j)

# %%
print(e_init.real - mycc.e_tot)
# Out:
# -2.220446049250313e-16

# %%
# comm.Barrier()
# if rank == 0:
#     print(f'# Propagating with {options["n_walkers"]*size} walkers')
#     print("# Equilibration sweeps:")
#     print("#   Iter \t Energy_HF \t Energy_PT \t Walltime")
#     print(f"  {0:5d} \t {e0[0]:.6f} \t {ept:.6f} \t {time.time() - init_time:.2f}")
# comm.Barrier()

sampler_eq = sampling.sampler(
    n_prop_steps=50, n_ene_blocks=5, n_sr_blocks=10, n_chol = sampler.n_chol)
for n in range(1,options["n_eql"]+1):
    prop_data, (wt, e0) =\
        sampler_eq.propagate_phaseless(
        ham,
        ham_data,
        prop,
        prop_data,
        trial,
        wave_data,
    )

    print(f"  {n:5d} \t {wt:.6f} \t {e0:.6f}")
# Out:
#       1 	 2499.831798 	 -1.023569+0.000000j
#       2 	 2499.588700 	 -1.023569+0.000000j
#       3 	 2499.480541 	 -1.023569+0.000000j

# %%
nsamples = 50
wt_sp_list = np.empty(nsamples)
e0_sp_list = np.empty(nsamples)

for i,n in enumerate(range(1,nsamples+1)):
    prop_data, (wt, e0) =\
        sampler_eq.propagate_phaseless(
        ham,
        ham_data,
        prop,
        prop_data,
        trial,
        wave_data,
    )

    wt_sp_list[i] = wt
    e0_sp_list[i] = e0.real

    # prop_data["e_estimate"] = 0.9 * prop_data["e_estimate"] + 0.1 * ept
    # prop_data["pop_control_ene_shift"] = prop_data["e_estimate"]
    print(f"  {n:5d} \t {wt:.6f} \t {e0:.6f}")
# Out:
#       1 	 2499.392972 	 -1.023569+0.000000j
#       2 	 2499.526368 	 -1.023569+0.000000j
#       3 	 2499.875157 	 -1.023569+0.000000j
#       4 	 2499.667311 	 -1.023569+0.000000j
#       5 	 2499.336621 	 -1.023569+0.000000j
#       6 	 2499.779383 	 -1.023569+0.000000j
#       7 	 2499.826304 	 -1.023569+0.000000j
#       8 	 2499.562201 	 -1.023569+0.000000j
#       9 	 2499.535816 	 -1.023569+0.000000j
#      10 	 2499.454445 	 -1.023569+0.000000j
#      11 	 2499.817321 	 -1.023569+0.000000j
#      12 	 2499.717482 	 -1.023569+0.000000j
#      13 	 2499.959122 	 -1.023569+0.000000j
#      14 	 2499.568803 	 -1.023569+0.000000j
#      15 	 2499.494128 	 -1.023569+0.000000j
#      16 	 2499.556152 	 -1.023569+0.000000j
#      17 	 2499.924499 	 -1.023569+0.000000j
#      18 	 2499.527371 	 -1.023569+0.000000j
#      19 	 2499.525837 	 -1.023569+0.000000j
#      20 	 2499.621327 	 -1.023569+0.000000j
#      21 	 2499.678426 	 -1.023569+0.000000j
#      22 	 2499.608497 	 -1.023569+0.000000j
#      23 	 2499.620942 	 -1.023569+0.000000j
#      24 	 2499.698998 	 -1.023569+0.000000j
#      25 	 2499.284934 	 -1.023569+0.000000j
#      26 	 2499.724704 	 -1.023569+0.000000j
#      27 	 2499.572257 	 -1.023569+0.000000j
#      28 	 2499.634049 	 -1.023569+0.000000j
#      29 	 2499.660432 	 -1.023569+0.000000j
#      30 	 2499.346487 	 -1.023569+0.000000j
#      31 	 2499.511530 	 -1.023569+0.000000j
#      32 	 2499.809452 	 -1.023569+0.000000j
#      33 	 2499.482094 	 -1.023569+0.000000j
#      34 	 2499.736252 	 -1.023569+0.000000j
#      35 	 2499.670743 	 -1.023569+0.000000j
#      36 	 2499.769206 	 -1.023569+0.000000j
#      37 	 2499.686702 	 -1.023569+0.000000j
#      38 	 2499.324446 	 -1.023569+0.000000j
#      39 	 2499.566155 	 -1.023569+0.000000j
#      40 	 2499.847500 	 -1.023569+0.000000j
#      41 	 2499.056270 	 -1.023569+0.000000j
#      42 	 2499.385535 	 -1.023569+0.000000j
#      43 	 2499.619110 	 -1.023569+0.000000j
#      44 	 2499.700516 	 -1.023569+0.000000j
#      45 	 2499.211933 	 -1.023569+0.000000j
#      46 	 2499.601717 	 -1.023569+0.000000j
#      47 	 2499.526786 	 -1.023569+0.000000j
#      48 	 2499.567996 	 -1.023569+0.000000j
#      49 	 2499.798695 	 -1.023569+0.000000j
#      50 	 2499.549366 	 -1.023569+0.000000j

# %%
prop_data['walker']

# %%
from ad_afqmc.prop_unrestricted import wavefunctions_restricted
trial_rhf = wavefunctions_restricted.rhf(trial.norb, trial.nelec, n_batch=options["n_batch"])

# %%
rhf_eloc = trial_rhf.calc_energy(prop_data['walkers'], ham_data, wave_data)
rhf_olp = trial_rhf.calc_overlap(prop_data['walkers'], ham_data, wave_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rhf_eloc = trial_rhf.calc_energy(prop_data['walkers'], ham_data, wave_data)
#       2 rhf_olp = trial_rhf.calc_overlap(prop_data['walkers'], ham_data, wave_data)
#
# File ~/sharmagroup/cs_afqmc/ad_afqmc/prop_unrestricted/wavefunctions_restricted.py:84, in wave_function_restricted.calc_energy(self, walkers, ham_data, wave_data)
#      79     energy_batch = vmap(self._calc_energy_restricted, in_axes=(0, None, None))(
#      80         walker_batch, ham_data, wave_data
#      81     )
#      82     return carry, energy_batch
# ---> 84 _, energies = lax.scan(
#      85     scanned_fun,
#      86     None,
#      87     walkers.reshape(self.n_batch, batch_size, self.norb, -1),
#      88 )
#      89 return energies.reshape(n_walkers)
#
#     [... skipping hidden 10 frame]
#
# File ~/sharmagroup/cs_afqmc/ad_afqmc/prop_unrestricted/wavefunctions_restricted.py:79, in wave_function_restricted.calc_energy.<locals>.scanned_fun(carry, walker_batch)
#      78 def scanned_fun(carry, walker_batch):
# ---> 79     energy_batch = vmap(self._calc_energy_restricted, in_axes=(0, None, None))(
#      80         walker_batch, ham_data, wave_data
#      81     )
#      82     return carry, energy_batch
#
#     [... skipping hidden 22 frame]
#
# File ~/sharmagroup/cs_afqmc/ad_afqmc/prop_unrestricted/wavefunctions_restricted.py:265, in rhf._calc_energy_restricted(self, walker, ham_data, wave_data)
#     261 @partial(jit, static_argnums=0)
#     262 def _calc_energy_restricted(
#     263     self, walker: jax.Array, ham_data: dict, wave_data: dict
#     264 ) -> jax.Array:
# --> 265     h0, rot_h1, rot_chol = ham_data["h0"], ham_data["rot_h1"], ham_data["rot_chol"]
#     266     ene0 = h0
#     267     green_walker = self._calc_green(walker, wave_data)
#
# KeyError: 'rot_h1'

# %%
from matplotlib import pyplot as plt
e0_avg = e0_sp_list.mean()
e0_avg_std = np.std(e0_sp_list, ddof=1) / np.sqrt(len(e0_sp_list))
ept_avg = ept_sp_list.mean()
ept_avg_std = np.std(ept_sp_list, ddof=1) / np.sqrt(len(ept_sp_list))
print(f'AFQMC/HF average = {e0_avg}, std = {e0_avg_std}')
print(f'AFQMC/PT average = {ept_avg}, std = {ept_avg_std}')
plt.plot(e0_sp_list,'.-',label='HF',color='C0')
plt.plot([e0_avg]*len(e0_sp_list),'--',color='C0')
plt.plot(ept_sp_list,'.-',label='PT',color='C1')
plt.plot([ept_avg]*len(ept_sp_list),'--',color='C1')
plt.plot(te_te_list+mf.e_tot,'.-',label='TETE',color='C2')
# plt.plot(te_sp_list+mf.e_tot+20,'.-',label='TE',color='C3')
plt.legend()
plt.show()
# Out:
# AFQMC/HF average = -108.63794290705977, std = 0.006273447896687275
# AFQMC/PT average = -108.66365812824462, std = 0.0009793696532658246

# %%
glb_wt = np.sum(wt_sp_list)

glb_t = np.sum(wt_sp_list * t_sp_list) / glb_wt
glb_e0 = np.sum(wt_sp_list * e0_sp_list) / glb_wt
glb_te = np.sum(wt_sp_list * te_sp_list) / glb_wt

glb_ept = glb_e0 + glb_te - glb_t * (glb_e0 - h0)
dE = np.array([-glb_e0+h0,1-glb_t,1])
cov_te0e1 = np.cov([t_sp_list, e0_sp_list, te_sp_list])
ept_cov = np.sqrt(dE @ cov_te0e1 @ dE)/np.sqrt((n+1)*size)

print(f'AFQMC/PT glb cov = {glb_ept:.4f} +/- {ept_cov:.4f}')
# Out:
# AFQMC/PT glb cov = -108.6649 +/- 0.0010

# %%
wt_list = wt_sp_list
wt_t_list = wt_sp_list * t_sp_list
wt_e0_list = wt_sp_list * e0_sp_list
wt_te_list = wt_sp_list * te_sp_list

# %%
blk_size = 2
blk_wt_list = wt_list.reshape(-1, blk_size).sum(axis=1)
blk_wt_t_list = wt_t_list.reshape(-1, blk_size).sum(axis=1)
blk_wt_e0_list = wt_e0_list.reshape(-1, blk_size).sum(axis=1)
blk_wt_te_list = wt_te_list.reshape(-1, blk_size).sum(axis=1)

blk_t_list = blk_wt_t_list / blk_wt_list
blk_e0_list = blk_wt_e0_list / blk_wt_list
blk_te_list = blk_wt_te_list / blk_wt_list

# %%
glb_wt = np.sum(blk_wt_list)
glb_t = np.sum(blk_wt_list * blk_wt_t_list) / glb_wt
glb_e0 = np.sum(blk_wt_list * blk_wt_e0_list) / glb_wt
glb_te = np.sum(blk_wt_list * blk_wt_te_list) / glb_wt

glb_ept = glb_e0 + glb_te - glb_t * (glb_e0 - h0)
dE = np.array([-glb_e0+h0,1-glb_t,1])
cov_te0e1 = np.cov([blk_t_list, blk_e0_list, blk_te_list])
ept_cov = np.sqrt(dE @ cov_te0e1 @ dE)/np.sqrt((n+1)*size)

print(f'AFQMC/PT glb cov = {glb_ept:.4f} +/- {ept_cov:.4f}')
# Out:
# AFQMC/PT glb cov = 4646803.6558 +/- 149.0173

# %%
blk_size = 2
blk_wt_list = wt_list.reshape(-1, blk_size)
blk_wt_t_list = wt_t_list.reshape(-1, blk_size)
blk_wt_e0_list = wt_e0_list.reshape(-1, blk_size)
blk_wt_te_list = wt_te_list.reshape(-1, blk_size)

glb_ept = glb_e0 + glb_te - glb_t * (glb_e0 - h0)
dE = np.array([-glb_e0+h0,1-glb_t,1])
cov_te0e1 = np.cov([t_sp_list, e0_sp_list, te_sp_list])
ept_cov = np.sqrt(dE @ cov_te0e1 @ dE)/np.sqrt((n+1)*size)

print(f'AFQMC/PT glb cov = {glb_ept:.4f} +/- {ept_cov:.4f}')

# %%
rho_e0
# Out:
# array([-2.17098876, -2.18138733, -2.1740445 , -2.18425509, -2.18178787,
#        -2.17630894, -2.17028348, -2.17610686, -2.17430512, -2.1790051 ,
#        -2.17265045, -2.18281089, -2.17099958, -2.16691435, -2.16798792,
#        -2.17630962, -2.18695648, -2.17671218, -2.17556064, -2.17042271,
#        -2.1768688 , -2.16145153, -2.17078216, -2.16445097, -2.16926911,
#        -2.16719207, -2.17612613, -2.16913996, -2.17393945, -2.16948587,
#        -2.16672907, -2.16971558, -2.17847985, -2.16862898, -2.1729198 ,
#        -2.17218209, -2.17046066, -2.18233159, -2.17202735, -2.17522561,
#        -2.16415297, -2.17442972, -2.17052904, -2.16923439, -2.17010375,
#        -2.16813818, -2.17140207, -2.1680249 , -2.16571808, -2.17308923])

# %%
rn_rho_e0 = rho_e0.reshape(-1, 2).mean(axis=1)
print(rn_rho_e0.sum())
# Out:
# -54.31901342780237
