# %%
from pyscf import gto, scf, cc
import numpy as np
from jax import numpy as jnp
from jax import vmap, jvp, jit
import jax
from functools import partial

a = 2 # 2aB
nH = 2
atoms = ""
for i in range(nH):
    atoms += f"O {i*a:.5f} 0.00000 0.00000 \n"

mol = gto.M(atom=atoms, basis="sto6g", unit='bohr', spin=0, verbose=4)
mol.build()

mf = scf.UHF(mol)
mf.kernel()

mo = mf.stability()[0]
dm = mf.make_rdm1(mo,mf.mo_occ)
mf.kernel(dm0=dm)
mo = mf.stability()[0]
dm = mf.make_rdm1(mo,mf.mo_occ)
mf.kernel(dm0=dm)


nfrozen = 2
mycc = cc.CCSD(mf,frozen=nfrozen)
mycc.kernel()[0]
# Out:
# System: uname_result(system='Linux', node='sharmagroup-rn', release='6.14.0-37-generic', version='#37~24.04.1-Ubuntu SMP PREEMPT_DYNAMIC Thu Nov 20 10:25:38 UTC 2', machine='x86_64')  Threads 16
# Python 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0]
# numpy 2.3.1  scipy 1.16.2  h5py 3.14.0
# Date: Sat Jan  3 18:06:57 2026
# PySCF version 2.11.0
# PySCF path  /home/sharmagroup/sharmagroup/pyscf
# GIT HEAD (branch master) 3d1768f5e33b144b606c3d2c81c12ee54d794501
#
# [ENV] PYSCF_EXT_PATH /home/sharmagroup/sharmagroup/pyscf-forge
# [CONFIG] conf_file None
# [INPUT] verbose = 4
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 16
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = bohr
# [INPUT] Symbol           X                Y                Z      unit          X                Y                Z       unit  Magmom
# [INPUT]  1 O      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr   0.0
# [INPUT]  2 O      1.058354421840   0.000000000000   0.000000000000 AA    2.000000000000   0.000000000000   0.000000000000 Bohr   0.0
#
# nuclear repulsion = 32
# number of shells = 6
# number of NR pGTOs = 60
# number of NR cGTOs = 10
# basis = sto6g
# ecp = {}
# CPU time:         0.56
#
#
# ******** <class 'pyscf.scf.uhf.UHF'> ********
# method = UHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmp2zoqpcm3
# max_memory 4000 MB (current use 260 MB)
# number electrons alpha = 8  beta = 8
# Set gradient conv threshold to 3.16228e-05
# init E= -149.470668599169
#
# WARN: alpha nocc = 8  HOMO -0.120594608954649 >= LUMO -0.120594608954648
#
#
# WARN: beta  nocc = 8  HOMO -0.129256688423933 >= LUMO -0.129256688423932
#
#
# WARN: system HOMO -0.129256688423933 >= system LUMO -0.129256688423932
#
# cycle= 1 E= -148.879533506383  delta_E= 0.591  |g|= 0.0804  |ddm|= 1.79
#   alpha nocc = 8  HOMO = -0.298784338169546  LUMO = 0.240432343522121
#   beta  nocc = 8  HOMO = -0.299026921239053  LUMO = 0.240189760452614
# cycle= 2 E= -148.882152109518  delta_E= -0.00262  |g|= 0.0161  |ddm|= 0.107
#   alpha nocc = 8  HOMO = -0.297287361650235  LUMO = 0.242466871451986
#   beta  nocc = 8  HOMO = -0.297350229004804  LUMO = 0.242404004097417
# cycle= 3 E= -148.882614914368  delta_E= -0.000463  |g|= 0.0107  |ddm|= 0.0421
#   alpha nocc = 8  HOMO = -0.297377187022154  LUMO = 0.24300956194808
#   beta  nocc = 8  HOMO = -0.297401021427307  LUMO = 0.242985727542928
# cycle= 4 E= -148.883042946772  delta_E= -0.000428  |g|= 0.0125  |ddm|= 0.0335
#   alpha nocc = 8  HOMO = -0.299453191436883  LUMO = 0.245268536299206
#   beta  nocc = 8  HOMO = -0.299506749775597  LUMO = 0.245214977960503
# cycle= 5 E= -148.881605590672  delta_E= 0.00144  |g|= 0.000383  |ddm|= 0.21
#   alpha nocc = 8  HOMO = -0.294440852720138  LUMO = 0.240191352502656
#   beta  nocc = 8  HOMO = -0.294441725877554  LUMO = 0.240190479345236
# cycle= 6 E= -148.88160512447  delta_E= 4.66e-07  |g|= 0.000184  |ddm|= 0.00785
#   alpha nocc = 8  HOMO = -0.296279979312085  LUMO = 0.242032674690199
#   beta  nocc = 8  HOMO = -0.296279979379715  LUMO = 0.242032674622568
# cycle= 7 E= -148.881604824403  delta_E= 3e-07  |g|= 3.23e-06  |ddm|= 0.00301
#   alpha nocc = 8  HOMO = -0.29625152681533  LUMO = 0.242004219952473
#   beta  nocc = 8  HOMO = -0.296251526844365  LUMO = 0.24200421992344
# cycle= 8 E= -148.881604824331  delta_E= 7.14e-11  |g|= 1.54e-06  |ddm|= 2.72e-05
#   alpha nocc = 8  HOMO = -0.296225559810647  LUMO = 0.241978250780503
#   beta  nocc = 8  HOMO = -0.29622555979486  LUMO = 0.241978250796289
# Extra cycle  E= -148.881604824341  delta_E= -9.72e-12  |g|= 1.86e-06  |ddm|= 5.18e-06
# converged SCF energy = -148.881604824341  <S^2> = 5.4957283e-10  2S+1 = 1
# uhf_internal: lowest eigs of H = [-2.49586278e-02  5.18507806e-12  7.20987811e-01]
# <class 'pyscf.scf.uhf.UHF'> wavefunction has an internal instability
#
#
# ******** <class 'pyscf.scf.uhf.UHF'> ********
# method = UHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmp2zoqpcm3
# max_memory 4000 MB (current use 285 MB)
# number electrons alpha = 8  beta = 8
# Set gradient conv threshold to 3.16228e-05
# init E= -148.724483207495
#   alpha nocc = 8  HOMO = -0.285662211419711  LUMO = 0.320036579881205
#   beta  nocc = 8  HOMO = -0.285604445682101  LUMO = 0.320488953505453
# cycle= 1 E= -148.831123538851  delta_E= -0.107  |g|= 0.133  |ddm|= 0.403
#   alpha nocc = 8  HOMO = -0.289161299546807  LUMO = 0.316416857088918
#   beta  nocc = 8  HOMO = -0.289151011481264  LUMO = 0.316468819420658
# cycle= 2 E= -148.858304271687  delta_E= -0.0272  |g|= 0.0797  |ddm|= 0.194
#   alpha nocc = 8  HOMO = -0.294017743081046  LUMO = 0.294930566342638
#   beta  nocc = 8  HOMO = -0.294026537006135  LUMO = 0.294851244106169
# cycle= 3 E= -148.877633549861  delta_E= -0.0193  |g|= 0.0244  |ddm|= 0.295
#   alpha nocc = 8  HOMO = -0.295088942220521  LUMO = 0.269995905383827
#   beta  nocc = 8  HOMO = -0.295089049705907  LUMO = 0.270002590565342
# cycle= 4 E= -148.880685524056  delta_E= -0.00305  |g|= 0.0099  |ddm|= 0.139
#   alpha nocc = 8  HOMO = -0.295427781763815  LUMO = 0.258595378716461
#   beta  nocc = 8  HOMO = -0.295430642286445  LUMO = 0.258567822818754
# cycle= 5 E= -148.88150886738  delta_E= -0.000823  |g|= 0.00382  |ddm|= 0.0932
#   alpha nocc = 8  HOMO = -0.295522763359858  LUMO = 0.255912858411506
#   beta  nocc = 8  HOMO = -0.295522631331082  LUMO = 0.255910775202925
# cycle= 6 E= -148.881622560037  delta_E= -0.000114  |g|= 0.00267  |ddm|= 0.0259
#   alpha nocc = 8  HOMO = -0.295575735581069  LUMO = 0.254529521877092
#   beta  nocc = 8  HOMO = -0.295576729022834  LUMO = 0.254519976621441
# cycle= 7 E= -148.881670263674  delta_E= -4.77e-05  |g|= 0.0021  |ddm|= 0.0147
#   alpha nocc = 8  HOMO = -0.295616045186291  LUMO = 0.253539737964879
#   beta  nocc = 8  HOMO = -0.295616192601416  LUMO = 0.253536289346327
# cycle= 8 E= -148.881699334485  delta_E= -2.91e-05  |g|= 0.00172  |ddm|= 0.0112
#   alpha nocc = 8  HOMO = -0.295551132172784  LUMO = 0.255211246398931
#   beta  nocc = 8  HOMO = -0.295551206022995  LUMO = 0.255207148043347
# cycle= 9 E= -148.881648232067  delta_E= 5.11e-05  |g|= 0.00237  |ddm|= 0.0184
#   alpha nocc = 8  HOMO = -0.295729961340397  LUMO = 0.250857116534576
#   beta  nocc = 8  HOMO = -0.295729968059134  LUMO = 0.250858725192103
# cycle= 10 E= -148.88175453253  delta_E= -0.000106  |g|= 0.00074  |ddm|= 0.052
#   alpha nocc = 8  HOMO = -0.295804849360739  LUMO = 0.249252675492112
#   beta  nocc = 8  HOMO = -0.295804837563796  LUMO = 0.24925279040708
# cycle= 11 E= -148.881769525084  delta_E= -1.5e-05  |g|= 0.00022  |ddm|= 0.0234
#   alpha nocc = 8  HOMO = -0.295811305834664  LUMO = 0.249072565639472
#   beta  nocc = 8  HOMO = -0.295811287854229  LUMO = 0.249072707903834
# cycle= 12 E= -148.88177017268  delta_E= -6.48e-07  |g|= 0.000172  |ddm|= 0.00243
#   alpha nocc = 8  HOMO = -0.295831393084597  LUMO = 0.248536031713443
#   beta  nocc = 8  HOMO = -0.295831389929433  LUMO = 0.248536068527516
# cycle= 13 E= -148.881771227634  delta_E= -1.05e-06  |g|= 3.19e-05  |ddm|= 0.00768
#   alpha nocc = 8  HOMO = -0.295837564899826  LUMO = 0.248367040729
#   beta  nocc = 8  HOMO = -0.295837566188267  LUMO = 0.24836703182352
# cycle= 14 E= -148.881771262494  delta_E= -3.49e-08  |g|= 1.09e-05  |ddm|= 0.00248
#   alpha nocc = 8  HOMO = -0.295836938603581  LUMO = 0.248383382489427
#   beta  nocc = 8  HOMO = -0.295836939435789  LUMO = 0.248383378272878
# cycle= 15 E= -148.881771265396  delta_E= -2.9e-09  |g|= 6.73e-06  |ddm|= 0.000243
#   alpha nocc = 8  HOMO = -0.295836578816633  LUMO = 0.248392785004588
#   beta  nocc = 8  HOMO = -0.295836580166829  LUMO = 0.248392774424878
# cycle= 16 E= -148.881771266447  delta_E= -1.05e-09  |g|= 4.37e-06  |ddm|= 0.000139
#   alpha nocc = 8  HOMO = -0.295836318772526  LUMO = 0.248399671728028
#   beta  nocc = 8  HOMO = -0.295836317619843  LUMO = 0.248399677449962
# cycle= 17 E= -148.881771266931  delta_E= -4.84e-10  |g|= 2.63e-06  |ddm|= 0.000102
#   alpha nocc = 8  HOMO = -0.295836409504615  LUMO = 0.248402033035613
#   beta  nocc = 8  HOMO = -0.295836409842635  LUMO = 0.24840203050918
# Extra cycle  E= -148.881771266946  delta_E= -1.51e-11  |g|= 2.55e-06  |ddm|= 4.25e-06
# converged SCF energy = -148.881771266946  <S^2> = 0.052560662  2S+1 = 1.1001103
# uhf_internal: lowest eigs of H = [2.39357128e-08 4.91821386e-02 4.32785031e-01]
# <class 'pyscf.scf.uhf.UHF'> wavefunction is stable in the internal stability analysis
#
#
# ******** <class 'pyscf.scf.uhf.UHF'> ********
# method = UHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# diis_damp = 0
# SCF conv_tol = 1e-09
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /tmp/tmp2zoqpcm3
# max_memory 4000 MB (current use 286 MB)
# number electrons alpha = 8  beta = 8
# Set gradient conv threshold to 3.16228e-05
# init E= -148.881771266946
#   alpha nocc = 8  HOMO = -0.295836404273523  LUMO = 0.248402243870629
#   beta  nocc = 8  HOMO = -0.295836404087038  LUMO = 0.248402244937065
# cycle= 1 E= -148.88177126696  delta_E= -1.41e-11  |g|= 2.48e-06  |ddm|= 4.11e-06
#   alpha nocc = 8  HOMO = -0.295836392661722  LUMO = 0.248402457553358
#   beta  nocc = 8  HOMO = -0.295836392719198  LUMO = 0.248402457135019
# Extra cycle  E= -148.881771266973  delta_E= -1.34e-11  |g|= 2.42e-06  |ddm|= 3.99e-06
# converged SCF energy = -148.881771266973  <S^2> = 0.052564173  2S+1 = 1.1001167
#
# ******** <class 'pyscf.cc.uccsd.UCCSD'> ********
# CC2 = 0
# CCSD nocc = (np.int64(6), np.int64(6)), nmo = (8, 8)
# frozen orbitals 2
# max_cycle = 50
# direct = 0
# conv_tol = 1e-07
# conv_tol_normt = 1e-06
# diis_space = 6
# diis_start_cycle = 0
# diis_start_energy_diff = 1e+09
# max_memory 4000 MB (current use 286 MB)
# Init t2, MP2 energy = -0.0803801487292813
# Init E_corr(UCCSD) = -0.0803801487364701
# cycle = 1  E_corr(UCCSD) = -0.0928340461746308  dE = -0.0124538974  norm(t1,t2) = 0.0546424
# cycle = 2  E_corr(UCCSD) = -0.097033355648192  dE = -0.00419930947  norm(t1,t2) = 0.0359817
# cycle = 3  E_corr(UCCSD) = -0.103909473606228  dE = -0.00687611796  norm(t1,t2) = 0.0257161
# cycle = 4  E_corr(UCCSD) = -0.103259940455572  dE = 0.000649533151  norm(t1,t2) = 0.0106416
# cycle = 5  E_corr(UCCSD) = -0.104104599397172  dE = -0.000844658942  norm(t1,t2) = 0.00922719
# cycle = 6  E_corr(UCCSD) = -0.103914996972509  dE = 0.000189602425  norm(t1,t2) = 0.00858053
# cycle = 7  E_corr(UCCSD) = -0.106286646077861  dE = -0.00237164911  norm(t1,t2) = 0.00675314
# cycle = 8  E_corr(UCCSD) = -0.10700913703399  dE = -0.000722490956  norm(t1,t2) = 0.00175099
# cycle = 9  E_corr(UCCSD) = -0.107064510465515  dE = -5.53734315e-05  norm(t1,t2) = 0.000275509
# cycle = 10  E_corr(UCCSD) = -0.107072079972304  dE = -7.56950679e-06  norm(t1,t2) = 0.000141318
# cycle = 11  E_corr(UCCSD) = -0.107075284840596  dE = -3.20486829e-06  norm(t1,t2) = 8.3574e-05
# cycle = 12  E_corr(UCCSD) = -0.107074703978963  dE = 5.80861633e-07  norm(t1,t2) = 2.61517e-05
# cycle = 13  E_corr(UCCSD) = -0.107072747584646  dE = 1.95639432e-06  norm(t1,t2) = 1.21888e-05
# cycle = 14  E_corr(UCCSD) = -0.107072813079192  dE = -6.54945453e-08  norm(t1,t2) = 1.68141e-06
# cycle = 15  E_corr(UCCSD) = -0.107073019695855  dE = -2.06616664e-07  norm(t1,t2) = 1.28914e-06
# cycle = 16  E_corr(UCCSD) = -0.107073075327443  dE = -5.56315874e-08  norm(t1,t2) = 7.97509e-07
# UCCSD converged
# E(UCCSD) = -148.9888443423009  E_corr = -0.1070730753274426
# np.float64(-0.10707307532744263)

# %%
# example for PT2
options = {'n_eql': 3,
           'n_prop_steps': 50,
            'n_ene_blocks': 1,
            'n_sr_blocks': 5,
            'n_blocks': 10,
            'n_walkers': 5,
            'seed': 2,
            'walker_type': 'uhf',
            'trial': 'uccsd_pt2',
            'dt':0.005,
            'free_projection':False,
            'ad_mode':None,
            'use_gpu': False,
            }

from ad_afqmc.prop_unrestricted import prop_unrestricted
prop_unrestricted.prep_afqmc(mycc,options,chol_cut=1e-5)
prop_unrestricted.run_afqmc(options,nproc=1)
# Out:
# #
# # Preparing AFQMC calculation
# # If you import pyscf cc modules and use MPI for AFQMC in the same script, finalize MPI before calling the AFQMC driver.
# # Calculating Cholesky integrals
# # Finished calculating Cholesky integrals
# #
# # Size of the correlation space:
# # Number of electrons: (6, 6)
# # Number of basis functions: 8
# # Number of Cholesky vectors: 42
# #
# # running AFQMC on CPU
# # AFQMC script: /home/sharmagroup/sharmagroup/cs_afqmc/ad_afqmc/prop_unrestricted/run_afqmc_ccsd_pt2.py
# # Hostname: sharmagroup-rn
# # System Type: Linux
# # Machine Type: x86_64
# # Processor: x86_64
# # Hostname: sharmagroup-rn
# # System Type: Linux
# # Machine Type: x86_64
# # Processor: x86_64
# # Number of MPI ranks: 1
# #
# # norb: 8
# # nelec: (6, 6)
# #
# # n_eql: 3
# # n_prop_steps: 50
# # n_ene_blocks: 1
# # n_sr_blocks: 5
# # n_blocks: 10
# # n_walkers: 5
# # seed: 2
# # walker_type: uhf
# # trial: uccsd_pt2
# # dt: 0.005
# # free_projection: False
# # use_gpu: False
# # n_exp_terms: 6
# # orbital_rotation: True
# # do_sr: True
# # symmetry: False
# # save_walkers: False
# # ene0: 0.0
# # n_batch: 1
# # LNO: False
# # orbE: 0
# # maxError: 0.001
# #
# # Propagating with 5 walkers
# # Equilibration sweeps:
# #   Iter  	    <exp(t1)> 	 <t2> 	 	 <e0> 	 	 <e1> 	 	    energy 	 Walltime
#       0 	   0.991126 	 0.000000 	-48.300993 	 -0.104233 	   -148.987793 	 1.05
#       1 	   0.999709 	 0.497775 	 -48.901509 	 -24.255573 	   -148.971413 	 2.11
#       2 	   1.007989 	 0.592959 	 -49.256822 	 -28.946622 	   -148.986656 	 2.95
#       3 	   1.007654 	 0.164748 	 -49.245695 	 -8.014213 	   -148.983751 	 3.14
# #
# # Sampling sweeps:
# #  Iter 	 energy 	 error 	 	 Walltime
#      1 	 	 -148.991923 	 0.001657 	  3.84
#      2 	 	 -148.995491 	 0.004647 	  3.86
#      3 	 	 -148.995611 	 0.003568 	  3.88
#      4 	 	 -148.992103 	 0.004912 	  3.90
#      5 	 	 -148.985007 	 0.008043 	  3.92
#      6 	 	 -148.987676 	 0.007234 	  3.94
#      7 	 	 -148.990145 	 0.006147 	  3.96
#      8 	 	 -148.994080 	 0.005777 	  3.98
#      9 	 	 -148.994941 	 0.004801 	  4.00
# # Number of outliers in post: 0
# # Final Results1:
# # h0 = -100.14915656
# # <exp(t1)> = 1.010353 +/- 0.000767
# # <t2> = 0.240727 +/- 0.028412
# # <e0> = -49.338397 +/- 0.040337
# # <e1> = -11.768467 +/- 1.384464
# # AFQMC/UCCSD_PT2 energy (covariance): -148.994941 +/- 0.004801
# # remove outliers in direct sampling:  0
# # AFQMC/UCCSD_PT2 energy (direct obs): -148.985693 +/- 0.004020
# # total run time: 4.00
