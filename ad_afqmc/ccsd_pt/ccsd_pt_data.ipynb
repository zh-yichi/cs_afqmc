# %%
import numpy as np
from matplotlib import pyplot as plt
def get_data(data):
    n = []
    e = []
    err = []
    for line in data.splitlines():
        if len(line) > 0:
            m = [int(line.split()[0])]
            n = np.hstack((n,m))
            energy = [float(line.split()[-3])]
            e = np.hstack((e,energy))
            error = [float(line.split()[-1])]
            err = np.hstack((err,error))
    e_per = e/n
    err_per = err/n
    return n,e_per,err_per

# %%
# H2
data1 = '''
1  AFQMC energy: -1.096072 +/- 0.00000
2  AFQMC energy: -2.19206 +/- 0.00005
4  AFQMC energy: -4.3838 +/- 0.0003
8  AFQMC energy: -8.7665 +/- 0.0003
16 AFQMC energy: -17.5296 +/- 0.0008
32 AFQMC energy: -35.051 +/- 0.002
50 AFQMC energy: -54.758 +/- 0.004
'''
data2 = '''
1  AFQMC/CCSD_PT energy: -1.096170 +/- 0.000017
2  AFQMC/CCSD_PT energy: -2.192324 +/- 0.000043
4  AFQMC/CCSD_PT energy: -4.384640 +/- 0.000107
8  AFQMC/CCSD_PT energy: -8.769068 +/- 0.000402
16 AFQMC/CCSD_PT energy: -17.539953 +/- 0.000645
32 AFQMC/CCSD_PT energy: -35.077183 +/- 0.001844
50 AFQMC/CCSD_PT energy: -54.804661 +/- 0.003729
'''
n1,e_per1,err_per1 = get_data(data1)
n2,e_per2,err_per2 = get_data(data2)
plt.errorbar(n1,e_per1,yerr=err_per1,fmt='.',capsize=5,label='AFQMC/CISD')
plt.plot(n1,e_per1, '--', color='C0', alpha=0.3)
plt.errorbar(n2,e_per2,yerr=err_per2,fmt='.',capsize=5,label='AFQMC/CCSD_PT')
plt.plot(n2,e_per2, '--', color='C1', alpha=0.3)
plt.xlabel('number of H2')
plt.ylabel('energy per H2')
plt.title('Test AFQMC/CCSD_PT SE non-interacting H2')
plt.legend()
plt.show()

# %%
# truncated CCSD trial guided by Hf 
# <CCSD|H|walkers><HF|walkers> * <HF|walkers>/CCSD|walkers>
# H2
# 1  AFQMC/CCSD_HF energy: -1.096071 +/- 0.000000
# 2  AFQMC/CCSD_HF energy: -2.191973 +/- 0.000044
# 4  AFQMC/CCSD_HF energy: -4.383381 +/- 0.000150
# 8  AFQMC/CCSD_HF energy: -8.764165 +/- 0.000305
# 16 AFQMC/CCSD_HF energy: -17.523157 +/- 0.000762
data1 = '''
1  AFQMC energy: -1.096072 +/- 0.00000
2  AFQMC energy: -2.19206 +/- 0.00005
4  AFQMC energy: -4.3838 +/- 0.0003
8  AFQMC energy: -8.7665 +/- 0.0003
16 AFQMC energy: -17.5296 +/- 0.0008
32 AFQMC energy: -35.051 +/- 0.002
'''
data2 = '''
1  AFQMC/CCSD_HF energy: -1.096071 +/- 0.000000
2  AFQMC/CCSD_PT energy: -2.191973 +/- 0.000044
4  AFQMC/CCSD_PT energy: -4.383381 +/- 0.000150
8  AFQMC/CCSD_PT energy: -8.764165 +/- 0.000305
16 AFQMC/CCSD_PT energy: -17.523157 +/- 0.000762
25 AFQMC/CCSD_PT energy: -27.372870 +/- 0.001295
'''
n1,e_per1,err_per1 = get_data(data1)
n2,e_per2,err_per2 = get_data(data2)
plt.errorbar(n1,e_per1,yerr=err_per1,fmt='.',capsize=5,label='AFQMC/CISD')
plt.plot(n1,e_per1, '--', color='C0', alpha=0.3)
plt.errorbar(n2,e_per2,yerr=err_per2,fmt='.',capsize=5,label='AFQMC/CCSD_HF')
plt.plot(n2,e_per2, '--', color='C1', alpha=0.3)
plt.xlabel('number of H2')
plt.ylabel('energy per H2')
plt.title('Test AFQMC/CCSD_HF SE non-interacting H2')
plt.legend()
plt.show()

# %%
# H3
# afqmc/ucisd
data1 = '''
1  AFQMC energy: -1.57330704 +/- 0.00000005
2  AFQMC energy: -3.14657 +/- 0.00002
4  AFQMC energy: -6.29294 +/- 0.00004
8  AFQMC energy: -12.58526 +/- 0.00008
16 AFQMC energy: -25.1691 +/- 0.0002
32 AFQMC energy: -50.3331 +/- 0.0007
'''
# afqmc/uccsd_pt
data2 = '''
1  AFQMC/CCSD_PT energy: -1.573331 +/- 0.000003
2  AFQMC/CCSD_PT energy: -3.146663 +/- 0.000005
4  AFQMC/CCSD_PT energy: -6.293313 +/- 0.000011
8  AFQMC/CCSD_PT energy: -12.586666 +/- 0.000025
16 AFQMC/CCSD_PT energy: -25.173284 +/- 0.000053
32 AFQMC/CCSD_PT energy: -50.346618 +/- 0.000104
'''
# afqmc/uccsd_pt2 (exact T1)
data3 = '''
1  AFQMC/CCSD_PT energy: -1.573341 +/- 0.000004
2  AFQMC/CCSD_PT energy: -3.146693 +/- 0.000009
4  AFQMC/CCSD_PT energy: -6.293342 +/- 0.000020
8  AFQMC/CCSD_PT energy: -12.586798 +/- 0.000043
16 AFQMC/CCSD_PT energy: -25.173438 +/- 0.000093
25 AFQMC/CCSD_PT energy: -39.333539 +/- 0.000139
'''
n1,e_per1,err_per1 = get_data(data1)
n2,e_per2,err_per2 = get_data(data2)
n3,e_per3,err_per3 = get_data(data3)
plt.errorbar(n1,e_per1,yerr=err_per1,fmt='.',capsize=5,label='AFQMC/UCISD')
plt.plot(n1,e_per1, '--', color='C0', alpha=0.3)
plt.errorbar(n2,e_per2,yerr=err_per2,fmt='.',capsize=5,label='AFQMC/UCCSD_PT')
plt.plot(n2,e_per2, '--', color='C1', alpha=0.3)
plt.errorbar(n3,e_per3,yerr=err_per3,fmt='.',capsize=5,label='AFQMC/UCCSD_PT2 (exact T1)')
plt.plot(n3,e_per3, '--', color='C2', alpha=0.3)
plt.xlabel('number of H3')
plt.ylabel('energy per H3')
plt.title('Test AFQMC/UCCSD_PT SE non-interacting H3')
plt.legend()
plt.show()

# %%
# H4 exact T1*5
# 1  AFQMC/CCSD_PT energy: -2.165526 +/- 0.000066
# 2  AFQMC/CCSD_PT energy: -4.331244 +/- 0.000258
# 4  AFQMC/CCSD_PT energy: -8.662060 +/- 0.000580
# 8  AFQMC/CCSD_PT energy: -17.323116 +/- 0.000877
# 16 AFQMC/CCSD_PT energy: -34.648138 +/- 0.002807
# 25 AFQMC/CCSD_PT energy: -54.141892 +/- 0.005245
data1 = '''
1  AFQMC/CCSD_PT energy: -2.165526 +/- 0.000066
2  AFQMC/CCSD_PT energy: -4.331244 +/- 0.000258
4  AFQMC/CCSD_PT energy: -8.662060 +/- 0.000580
8  AFQMC/CCSD_PT energy: -17.323116 +/- 0.000877
16 AFQMC/CCSD_PT energy: -34.648138 +/- 0.002807
25 AFQMC/CCSD_PT energy: -54.141892 +/- 0.005245
'''
data2 = '''
1  AFQMC energy: -2.16526 +/- 0.00005
2  AFQMC energy: -4.33024 +/- 0.00009
4  AFQMC energy: -8.6591 +/- 0.0003
8  AFQMC energy: -17.31515791613727 +/- 1.439025e-03
16 AFQMC energy: -34.618 +/- 0.001
25 AFQMC energy: -54.080 +/- 0.003
'''
np.set_printoptions(5)
n1,e_per1,err_per1 = get_data(data1)
n2,e_per2,err_per2 = get_data(data2)
print('AFQMC/CCSD_PT2 energy per H4:', e_per1)
print('AFQMC/CISD energy per H4:', e_per2)
plt.errorbar(n1,e_per1,yerr=err_per1,fmt='.',capsize=5,label='AFQMC/CCSD_PT2_SMT')
plt.plot(n1,e_per1, '--', color='C0', alpha=0.3)
plt.errorbar(n2,e_per2,yerr=err_per2,fmt='.',capsize=5,label='AFQMC/CISD')
plt.plot(n2,e_per2, '--', color='C1', alpha=0.3)
plt.xlabel('number of H4')
plt.ylabel('energy per H4')
plt.title('AFQMC/CCSD_PT exact T1 non-interacting H4')
plt.legend()
plt.show()
# Out:
# AFQMC/CCSD_PT2 energy per H4: [-2.16553 -2.16562 -2.16552 -2.16539 -2.16551 -2.16568]
# AFQMC/CISD energy per H4: [-2.16526 -2.16512 -2.16478 -2.16439 -2.16363 -2.1632 ]

# %%
# N2
data1 = '''
1  AFQMC energy: -108.7110 +/- 0.0001
5  AFQMC energy: -543.5542 +/- 0.0008
10 AFQMC energy: -1087.108 +/- 0.002
15 AFQMC energy: -1630.661 +/- 0.003
'''
data2 = '''
1  AFQMC/CCSD_PT energy: -108.710187 +/- 0.000089
5  AFQMC/CCSD_PT energy: -543.551985 +/- 0.001202
10 AFQMC/CCSD_PT energy: -1087.102247 +/- 0.002270
15 AFQMC/CCSD_PT energy: -1630.659798 +/- 0.003655
'''
n1,e_per1,err_per1 = get_data(data1)
n2,e_per2,err_per2 = get_data(data2)
plt.errorbar(n1,e_per1,yerr=err_per1,fmt='.',capsize=5,label='AFQMC/CISD')
plt.plot(n1,e_per1, '--', color='C0', alpha=0.3)
plt.errorbar(n2,e_per2,yerr=err_per2,fmt='.',capsize=5,label='AFQMC/CCSD_PT')
plt.plot(n2,e_per2, '--', color='C1', alpha=0.3)
plt.xlabel('number of N2')
plt.ylabel('energy per N2')
plt.legend()
plt.show()

# %%
# CO2
# E(CCSD) = -188.1294872754844 
# CCSD(T) energy: -188.14742928212362
# AFQMC/RHF energy: -188.1556 +/- 0.0006
# AFQMC/CISD energy: -188.1495 +/- 0.0001
# AFQMC/CCSD_PT energy: -188.1488 +/- 0.0002
# AFQMC/CCSD_PT2 energy: -188.1484 +/- 0.0004 (exact T1)

# %%
# Mol          CCSD(T)              AFQMC/CCSD_PT   
# C2H       -76.39855638        -76.399014 +/- 0.000051
# C2H2      -77.10924902        -77.109546 +/- 0.000064
# CF        -137.4748482        -137.475760 +/- 0.000192
# CH        -38.37935551        -38.380189 +/- 0.000024
# CH2       
# CH3       -39.71553966        -39.715980 +/- 0.000010
# CN        -92.48869527        -92.487483 +/- 0.000157
# CO        -113.0544306        -113.055092 +/- 0.000092
# CO2       -188.1474293        -188.148924 +/- 0.000137
# F2        -199.0963839        -199.098269 +/- 0.000057
# H2        -1.163426264        -1.163426 +/- 0.000001
# H2O       -76.24101779        -76.241701 +/- 0.000038
# H2O2      -151.1936301        -151.194724 +/- 0.000058
# HCN       -93.18832063        -93.189107 +/- 0.000157
# HCO       -113.5757054        -113.576087 +/- 0.000097
# HF        -100.2281312        -100.228669 +/- 0.000031
# HNO       -130.1696778        -130.172789 +/- 0.000079
# HO2       -150.5584809        -150.559452 +/- 0.000056
# N2        -109.2752986        -109.276029 +/- 0.000140
# NH        -55.09129056        -55.091499 +/- 0.000007
# NH2       -55.73250631        -55.732956 +/- 0.000013 
# NH3       -56.40191327        -56.402489 +/- 0.000029
# NO        -129.5977782        -129.598245 +/- 0.000077
# O2        -149.9856842        -149.985698 +/- 0.000084
# OF        -174.4979237        -174.498355 +/- 0.000059
# OH        -75.55923331        -75.559572 +/- 0.000015

# %%
# C2H:
# CCSD(T) energy: -76.39855638395595
# AFQMC/CCSD_PT energy: -76.399014 +/- 0.000051
# C2H2:
# CCSD(T) energy: -77.10924902519658
# AFQMC/CCSD_PT energy: -77.109546 +/- 0.000064
# CF:
# CCSD(T) energy: -137.4748481938497
# AFQMC/CCSD_PT energy: -137.475760 +/- 0.000192
# CH:
# CCSD(T) energy: -38.37935551046951
# AFQMC/CCSD_PT energy: -38.380189 +/- 0.000024
# CH3
# CCSD(T) energy: -39.715539657316164
# AFQMC/CCSD_PT energy: -39.715980 +/- 0.000010
# CN:
# CCSD(T) energy: -92.48869527497999
# AFQMC/CCSD_PT energy: -92.487483 +/- 0.000157
# CO:
# CCSD(T) energy: -113.05443062244996
# AFQMC/CCSD_PT energy: -113.055092 +/- 0.000092
# F2:
# CCSD(T) energy: -199.0963838645632
# AFQMC/CCSD_PT energy: -199.098269 +/- 0.000057
# H2:
# CCSD(T) energy: -1.1634262640654354
# AFQMC/CCSD_PT energy: -1.163426 +/- 0.000001
# H2O:
# CCSD(T) energy: -76.24101778900513
# AFQMC/CCSD_PT energy: -76.241701 +/- 0.000038
